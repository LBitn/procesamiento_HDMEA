# %% [markdown]
# # Depuracion
# Actividad supraumbral simulatanea

# %%
SCPpath = "/home/isabel/Dropbox/Proyects/Romero-Gutierrez/Scripts/Preprocesamiento/"
cd( SCPpath )
push!( LOAD_PATH, "." ); # folder que continen los modulos. Correr desde ahí dentro.
using AllFunctions # modulo personal
using JLD
Γ = OS( "linux" ); # establecer SO

# %%
filespath = "/home/isabel/Desktop/200819/acido_01/Events/STC_RAW";
JLDfiles = find_files( filespath, "jld", Γ );

# %%
brw_vars = load( "/home/isabel/Desktop/200819/acido_01/Vars/vars.jld" )[ "vars" ];
nchans = size( brw_vars[ "Chs" ], 1 )
thr = 30; # porcentaje de frames activos para ser considerado evento de satura
thr_Frames = Int( floor( nchans*( thr/100 ) ) );
println( "Threshold for overactivation: ", 
        thr, "%", " -> ", thr_Frames, " channels simultaneously activated" );
allMAYBES = load(
    "/home/isabel/Desktop/200819/acido_01/Vars/STC_RAW_vars.jld"
    )[ "all_MAYBES" ];
BaseMAYBES = allMAYBES;
# Out:
# Threshold for overactivation: 30% -> 1228 channels simultaneously activated

# %%
for A = 18:size( JLDfiles, 1 );
    Events = load( JLDfiles[ A ] );
    Vchannel = Events[ "Frames" ];
    if maximum( Vchannel ) >= thr_Frames
        OAF = findall( Vchannel .>= thr_Frames );
        println(
            size( OAF, 1 ),
            " frames are overactive, must be remove the false positives: file ", A );
        else
        OAF = [ ];
        println( "No frames are overactive with the above parameters: file ", A );
    end
    if !isempty( OAF )
        temp = zeros( Int, size( OAF, 1 ) );
        for i = 1:size( OAF, 1 )
            temp[ i ] = Int.( OAF[ i ][ 2 ] );
        end
        FV = Events["Events"];
        allsat = 0;
        for B = 1:size( temp, 1 )
            for C = 1:nchans
                if !isempty(
                        findall(
                            FV[ string( C ) ][ "Fr_Vol" ][ :, 1 ] .== temp[ B ] ) )
                    n_frames = size(
                        findall( 
                            FV[ string( C ) ][ "Fr_Vol" ][ :, 1 ] .== temp[ B ] ), 1 );
                    allMAYBES[ C, A ] = allMAYBES[ C, A ] - n_frames;
                    allsat = allsat + n_frames;
                end
            end
        end
        println( allsat," events removed." );
    end
end
DepMAYBES = allMAYBES;
# Out:
# 1 frames are overactive, must be remove the false positives: file 18
# No frames are overactive with the above parameters: file 19
# No frames are overactive with the above parameters: file 20
# No frames are overactive with the above parameters: file 21
# No frames are overactive with the above parameters: file 22
# No frames are overactive with the above parameters: file 23
# No frames are overactive with the above parameters: file 24
# No frames are overactive with the above parameters: file 25
# No frames are overactive with the above parameters: file 26
# No frames are overactive with the above parameters: file 27
# No frames are overactive with the above parameters: file 28
# No frames are overactive with the above parameters: file 29
# No frames are overactive with the above parameters: file 30
# No frames are overactive with the above parameters: file 31
# No frames are overactive with the above parameters: file 32
# No frames are overactive with the above parameters: file 33
# No frames are overactive with the above parameters: file 34
# No frames are overactive with the above parameters: file 35
# No frames are overactive with the above parameters: file 36
# No frames are overactive with the above parameters: file 37
# No frames are overactive with the above parameters: file 38
# No frames are overactive with the above parameters: file 39
# No frames are overactive with the above parameters: file 40
# No frames are overactive with the above parameters: file 41
# No frames are overactive with the above parameters: file 42
# No frames are overactive with the above parameters: file 43
# No frames are overactive with the above parameters: file 44
# No frames are overactive with the above parameters: file 45
# No frames are overactive with the above parameters: file 46
# No frames are overactive with the above parameters: file 47
# No frames are overactive with the above parameters: file 48
# No frames are overactive with the above parameters: file 49
# No frames are overactive with the above parameters: file 50
# No frames are overactive with the above parameters: file 51
# No frames are overactive with the above parameters: file 52
# No frames are overactive with the above parameters: file 53
# No frames are overactive with the above parameters: file 54
# No frames are overactive with the above parameters: file 55
# No frames are overactive with the above parameters: file 56
# No frames are overactive with the above parameters: file 57
# No frames are overactive with the above parameters: file 58
# No frames are overactive with the above parameters: file 59
# No frames are overactive with the above parameters: file 60
# No frames are overactive with the above parameters: file 61
# No frames are overactive with the above parameters: file 62
# No frames are overactive with the above parameters: file 63
# No frames are overactive with the above parameters: file 64
# No frames are overactive with the above parameters: file 65
# No frames are overactive with the above parameters: file 66
# No frames are overactive with the above parameters: file 67
# No frames are overactive with the above parameters: file 68
# No frames are overactive with the above parameters: file 69
# No frames are overactive with the above parameters: file 70
# No frames are overactive with the above parameters: file 71
# No frames are overactive with the above parameters: file 72
# No frames are overactive with the above parameters: file 73
# No frames are overactive with the above parameters: file 74
# No frames are overactive with the above parameters: file 75
# No frames are overactive with the above parameters: file 76
# No frames are overactive with the above parameters: file 77
# No frames are overactive with the above parameters: file 78
# No frames are overactive with the above parameters: file 79
# No frames are overactive with the above parameters: file 80
# No frames are overactive with the above parameters: file 81
# No frames are overactive with the above parameters: file 82
# No frames are overactive with the above parameters: file 83
# No frames are overactive with the above parameters: file 84
# No frames are overactive with the above parameters: file 85
# No frames are overactive with the above parameters: file 86
# No frames are overactive with the above parameters: file 87
# No frames are overactive with the above parameters: file 88
# No frames are overactive with the above parameters: file 89
# No frames are overactive with the above parameters: file 90

# %%
x = collect(1:sqrt(nchans));
y = collect(1:sqrt(nchans));

z = (sum( BaseMAYBES, dims = 2 ));
plot1 = heatmap( x, y, z, 
    grid = false, 
    aspect_ratio = 1, 
    fillcolor = :juno_grad,
    title = "Deteccion basal
    umbral estatico, Raw data",
    colorbar = true,
    background_colour = :white,
    framestyle = :axes,
    xlimits = (1,64),
    ylimits = (1,64),
    );

z = (sum( DepMAYBES, dims = 2 ));
plot2 = heatmap( x, y, z, 
    grid = false, 
    aspect_ratio = 1, 
    fillcolor = :juno_grad,
    title = "Deteccion depurada
    umbral estatico, Raw data",
    leg = false,
    colorbar = true,
    background_colour = :white,
    framestyle = :axes,
    xlimits = (1,64),
    ylimits = (1,64),
    );
gr( size = ( 800, 500 ) )
plot( plot1, plot2,
    layout = ( 1, 2 ),
)
