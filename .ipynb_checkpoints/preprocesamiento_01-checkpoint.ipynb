# %% [markdown]
# # pre-procesamiento 01
# #=
# El preprocesamiento consiste en acomodar los datos brw en una matriz que contenga 4096 filas
# (una por cada canal) y n columnas (una por cada cuadro muestral).
# Una vez organizados, se cortan fragmentos de 4096(n/m) donde m es divisor de n. El objetivo
# es obtener archivos de tamaño manejable tanto en tamaño muestral como en espacio de
# almacenamiento en disco y que no sature la memoria del equipo.
# En este caso están almacenados en formato Float16
# =#

# %%
SCPpath = "/home/isabel/Dropbox/Proyects/Romero-Gutierrez/Scripts/Preprocesamiento/" # path to SCPs
cd( SCPpath )
push!( LOAD_PATH, "." ); # folder que continen los modulos. Correr desde ahí dentro.
#
using AllFunctions # modulo personal
using JLD; # paquetes a usar en el script
# Out:
# ┌ Info: Precompiling JLD [4138dd39-2aa7-5051-a626-17a0bb65d9c8]
# └ @ Base loading.jl:1273

# %%
Γ = OS( "linux" ); # establecer SO a usar...es para mi lap si?
BRWpath = "/home/isabel/Desktop/200819/" # path donde están los experimentos
cd( BRWpath ) 
BRWfiles = find_files(BRWpath, "brw", Γ ); # todos los exp
BRWname = BRWfiles[ 1 ]; # solo uno, se puede hacer loop --------------------------------- !
println(string("Se procesará el archivo:", BRWname))

# %%
# Crear ahi folder para guardar cachos (uno para cada exp)

BRWpath = string( split( BRWname, "." )[ 1 ], Γ, "Process" ); 
checkpath( BRWpath ); # checar si el folder para guardar los cachos existe

#= variables del experimento para guardar al final con cada cacho, 
para evitar cargar el brw cada vez. En "dset" va el nombre del experimento =#

ν = brw_things( BRWname ); # variables útiles
ξ = ν[ "Chs" ]; # canales en numero, coord1, coord2
Σ = ν[ "dset" ]; # path al dataset (NO READ! to much)
ζ = ν[ "Factor" ]; # variables para...
ο = ν[ "Offset" ]; # conversión de voltaje
T = Int( size( Σ, 1 )/size( ξ, 1 ) ); # verdadero tiempo registrado
SR = round( ν[ "SamplingRate" ][ ], digits = 1 ); # .......Sampling Rate u k... 

# Se salva un diccionario con variables relevantes del archivo para uso posterior
Varsname = string(BRWpath, Γ ,"vars.jld"); # Salvando las variables de interés
save(Varsname,"vars", ν)
println( " Variables saved. ");

# %%
# tratando de encontrar un tamaño adecuado de cacho.

if isinteger( SR ) # así, se tienen cachos de 1 segundo
    if isinteger( T/SR )
        n_segments = Int.( T/SR );
        println( " Los cachos serán de 1 segundo " )
    end
elseif isinteger( T/floor( SR ) ) 
    n_segments = Int.( T/floor( SR ) );
    println( " Los cachos serán ~ 1 segundo " )
elseif isinteger( T/ceil( SR ) )
    n_segments = Int.( T/ceil( SR ) );
    println( " Los cachos serán ~ 1 segundo " )
else # si no, se hace un merequetengue
    div_T = div_n_ab( T );
    div_sec = div_T/SR;
    # rango de numero cachos que se quieren cortar, normalmente alto para tranajar a gusto
    hi = 4; lo = 2; # segundos
    if !isempty( div_T )
        # busca uno de los divisores de frames dentro del rango
        selected_divs = div_T[ findall( hi .>= div_sec .>= lo ) ];
    end
    if !isempty( selected_divs ) # si hubo, agarra el primero
        n_segments = Int(T/selected_divs[ 1 ]);
        println( " Los cachos serán de ", ( ( T/SR )/n_segments ) ," segundos " )
    else # si no hubo, uno predeterminado ya que
        n_segments = 60;
        println( " Los cachos serán de ", ( ( T/SR )/n_segments ) ," segundos " )
    end
end
#
# Out:
#  Los cachos serán de 2.0 segundos

# %%
# numero de espacios que ocupa el numero de segundos de duracion del experimento
n_char = length( string( Int( floor( T/SR ) ) ) ); 
# numero de espacios que ocupa el numero de cachos 
n_bins = length( string( n_segments ) );
ω = Int(ceil( T/n_segments ) ); # numero de frames finales (tamaño del cacho en frames)
ε = zeros( Int, n_segments, 2 ); # preallocate
ε[ :, 1 ] = collect( 1:ω:T ); # inicio y 
ε[ :, 2 ] = ε[ :, 1 ] .+ ω .- 1; # fin en frames de cada cacho (para cortar)
if !isinteger( T/n_segments )
    println("El ultimo cacho es más chico")
    ε[ end, 2 ] = T; # fin en frames de cada cacho (para cortar)
end

# %%
for i = 1:n_segments # numero de B a cortar (1-> 4096,1->ω)
    BIN = zeros( size( ξ, 1 ), ω ); # preallocate
    # valores correspondientes al BIN especifico
    # el canal 1,1 tiene el frame 1, 4097, 8193...etc
    β = collect( ( ε[ i, 1 ] - 1 ):1:ε[ i, 2 ] ); 
    for j = 1:ω
        # saca esos frames del machote seguido Σ, y ponlos en array en BIN
        BIN[ :, j ] = Σ[ ( β[ j ]*size( ξ, 1 ) ) + 1:( size( ξ, 1 )*β[ j + 1 ] ) ];
    end
    BIN = Float16.( ( BIN.*ζ ) .+ ο ); # conversion a volaje
    ini = lpad( string( Int(floor( ( β[ 1 ] )/SR ) ), "s" ), n_char + 1, "0" );
    eni = lpad( string( Int( floor( ( β[ end ] + 1 )/SR ) ), "s" ), n_char + 1, "0" );
    bin_time = string( ini,"-",eni );
    BINname = string( BRWpath, Γ, "BIN", lpad(i, n_bins, "0" ), "_", bin_time, ".jld" );     
    @time save( BINname, "data", BIN );
    println( lpad(i, n_bins, "0" ), " of ", n_segments, " saved" );
end
# Out:
#   7.408448 seconds (445.32 M allocations: 7.119 GiB, 13.86% gc time)
# 01 of 90 saved
#   5.656095 seconds (438.82 M allocations: 6.811 GiB, 18.59% gc time)
# 02 of 90 saved
#   5.533975 seconds (438.82 M allocations: 6.811 GiB, 18.43% gc time)
# 03 of 90 saved
#   5.804599 seconds (438.82 M allocations: 6.811 GiB, 18.52% gc time)
# 04 of 90 saved
#   5.507892 seconds (438.82 M allocations: 6.811 GiB, 18.59% gc time)
# 05 of 90 saved
#   5.601093 seconds (438.82 M allocations: 6.811 GiB, 18.39% gc time)
# 06 of 90 saved
#   5.644584 seconds (438.82 M allocations: 6.811 GiB, 19.02% gc time)
# 07 of 90 saved
#   5.544951 seconds (438.82 M allocations: 6.811 GiB, 18.82% gc time)
# 08 of 90 saved
#   5.526006 seconds (438.82 M allocations: 6.811 GiB, 18.63% gc time)
# 09 of 90 saved
#   5.555372 seconds (438.82 M allocations: 6.811 GiB, 18.53% gc time)
# 10 of 90 saved
#   5.455630 seconds (438.82 M allocations: 6.811 GiB, 18.54% gc time)
# 11 of 90 saved
#   5.486615 seconds (438.82 M allocations: 6.811 GiB, 18.47% gc time)
# 12 of 90 saved
#   5.512281 seconds (438.82 M allocations: 6.811 GiB, 18.48% gc time)
# 13 of 90 saved
#   5.611013 seconds (438.82 M allocations: 6.811 GiB, 18.88% gc time)
# 14 of 90 saved
#   5.601209 seconds (438.82 M allocations: 6.811 GiB, 18.43% gc time)
# 15 of 90 saved
#   5.583845 seconds (438.82 M allocations: 6.811 GiB, 18.46% gc time)
# 16 of 90 saved
#   5.604143 seconds (438.82 M allocations: 6.811 GiB, 18.52% gc time)
# 17 of 90 saved
#   5.663505 seconds (438.82 M allocations: 6.811 GiB, 18.84% gc time)
# 18 of 90 saved
#   5.589908 seconds (438.82 M allocations: 6.811 GiB, 18.62% gc time)
# 19 of 90 saved
#   5.551568 seconds (438.82 M allocations: 6.811 GiB, 18.70% gc time)
# 20 of 90 saved
#   5.745720 seconds (438.82 M allocations: 6.811 GiB, 18.39% gc time)
# 21 of 90 saved
#   5.617788 seconds (438.82 M allocations: 6.811 GiB, 18.43% gc time)
# 22 of 90 saved
#   5.872194 seconds (438.82 M allocations: 6.811 GiB, 18.58% gc time)
# 23 of 90 saved
#   5.554792 seconds (438.82 M allocations: 6.811 GiB, 18.73% gc time)
# 24 of 90 saved
#   5.538745 seconds (438.82 M allocations: 6.811 GiB, 18.60% gc time)
# 25 of 90 saved
#   5.556001 seconds (438.82 M allocations: 6.811 GiB, 18.79% gc time)
# 26 of 90 saved
#   5.551482 seconds (438.82 M allocations: 6.811 GiB, 18.80% gc time)
# 27 of 90 saved
#   5.566794 seconds (438.82 M allocations: 6.811 GiB, 18.73% gc time)
# 28 of 90 saved
#   5.812720 seconds (438.82 M allocations: 6.811 GiB, 18.61% gc time)
# 29 of 90 saved
#   5.751483 seconds (438.82 M allocations: 6.811 GiB, 18.56% gc time)
# 30 of 90 saved
#   5.569538 seconds (438.82 M allocations: 6.811 GiB, 18.76% gc time)
# 31 of 90 saved
#   5.572212 seconds (438.82 M allocations: 6.811 GiB, 18.76% gc time)
# 32 of 90 saved
#   5.469180 seconds (438.82 M allocations: 6.811 GiB, 18.55% gc time)
# 33 of 90 saved
#   5.819697 seconds (438.82 M allocations: 6.811 GiB, 18.98% gc time)
# 34 of 90 saved
#   6.181482 seconds (438.82 M allocations: 6.811 GiB, 18.76% gc time)
# 35 of 90 saved
#   5.738510 seconds (438.82 M allocations: 6.811 GiB, 18.42% gc time)
# 36 of 90 saved
#   5.469759 seconds (438.82 M allocations: 6.811 GiB, 18.70% gc time)
# 37 of 90 saved
#   5.863884 seconds (438.82 M allocations: 6.811 GiB, 18.79% gc time)
# 38 of 90 saved
#   5.760618 seconds (438.82 M allocations: 6.811 GiB, 19.10% gc time)
# 39 of 90 saved
#   5.542890 seconds (438.82 M allocations: 6.811 GiB, 18.72% gc time)
# 40 of 90 saved
#   5.780750 seconds (438.82 M allocations: 6.811 GiB, 19.01% gc time)
# 41 of 90 saved
#   5.565180 seconds (438.82 M allocations: 6.811 GiB, 18.82% gc time)
# 42 of 90 saved
#   5.790146 seconds (438.82 M allocations: 6.811 GiB, 19.33% gc time)
# 43 of 90 saved
#   5.633262 seconds (438.82 M allocations: 6.811 GiB, 19.06% gc time)
# 44 of 90 saved
#   5.597290 seconds (438.82 M allocations: 6.811 GiB, 18.89% gc time)
# 45 of 90 saved
#   5.548901 seconds (438.82 M allocations: 6.811 GiB, 19.11% gc time)
# 46 of 90 saved
#   5.527511 seconds (438.82 M allocations: 6.811 GiB, 18.84% gc time)
# 47 of 90 saved
#   5.775857 seconds (438.82 M allocations: 6.811 GiB, 18.72% gc time)
# 48 of 90 saved
#   5.915243 seconds (438.82 M allocations: 6.811 GiB, 18.74% gc time)
# 49 of 90 saved
#   5.856652 seconds (438.82 M allocations: 6.811 GiB, 19.19% gc time)
# 50 of 90 saved
#   5.706191 seconds (438.82 M allocations: 6.811 GiB, 19.12% gc time)
# 51 of 90 saved
#   6.001277 seconds (438.82 M allocations: 6.811 GiB, 18.91% gc time)
# 52 of 90 saved
#   5.683965 seconds (438.82 M allocations: 6.811 GiB, 18.93% gc time)
# 53 of 90 saved
#   5.928096 seconds (438.82 M allocations: 6.811 GiB, 18.93% gc time)
# 54 of 90 saved
#   5.850477 seconds (438.82 M allocations: 6.811 GiB, 19.00% gc time)
# 55 of 90 saved
#   5.898996 seconds (438.82 M allocations: 6.811 GiB, 18.59% gc time)
# 56 of 90 saved
#   5.968879 seconds (438.82 M allocations: 6.811 GiB, 19.03% gc time)
# 57 of 90 saved
#   5.752506 seconds (438.82 M allocations: 6.811 GiB, 19.25% gc time)
# 58 of 90 saved
#   5.556573 seconds (438.82 M allocations: 6.811 GiB, 18.92% gc time)
# 59 of 90 saved
#   5.663768 seconds (438.82 M allocations: 6.811 GiB, 18.99% gc time)
# 60 of 90 saved
#   5.768374 seconds (438.82 M allocations: 6.811 GiB, 18.91% gc time)
# 61 of 90 saved
#   5.528110 seconds (438.82 M allocations: 6.811 GiB, 18.76% gc time)
# 62 of 90 saved
#   5.935948 seconds (438.82 M allocations: 6.811 GiB, 18.79% gc time)
# 63 of 90 saved
#   5.529377 seconds (438.82 M allocations: 6.811 GiB, 18.85% gc time)
# 64 of 90 saved
#   5.518620 seconds (438.82 M allocations: 6.811 GiB, 18.92% gc time)
# 65 of 90 saved
#   5.524496 seconds (438.82 M allocations: 6.811 GiB, 18.81% gc time)
# 66 of 90 saved
#   5.587552 seconds (438.82 M allocations: 6.811 GiB, 18.78% gc time)
# 67 of 90 saved
#   5.480555 seconds (438.82 M allocations: 6.811 GiB, 18.81% gc time)
# 68 of 90 saved
#   5.496009 seconds (438.82 M allocations: 6.811 GiB, 18.85% gc time)
# 69 of 90 saved
#   5.532860 seconds (438.82 M allocations: 6.811 GiB, 18.94% gc time)
# 70 of 90 saved
#   5.618473 seconds (438.82 M allocations: 6.811 GiB, 18.36% gc time)
# 71 of 90 saved
#   5.574683 seconds (438.82 M allocations: 6.811 GiB, 18.72% gc time)
# 72 of 90 saved
#   5.766194 seconds (438.82 M allocations: 6.811 GiB, 18.66% gc time)
# 73 of 90 saved
#   6.009620 seconds (438.82 M allocations: 6.811 GiB, 18.77% gc time)
# 74 of 90 saved
#   5.969147 seconds (438.82 M allocations: 6.811 GiB, 18.52% gc time)
# 75 of 90 saved
#   5.836027 seconds (438.82 M allocations: 6.811 GiB, 18.74% gc time)
# 76 of 90 saved
#   5.850580 seconds (438.82 M allocations: 6.811 GiB, 19.37% gc time)
# 77 of 90 saved
#   5.790656 seconds (438.82 M allocations: 6.811 GiB, 18.89% gc time)
# 78 of 90 saved
#   5.613507 seconds (438.82 M allocations: 6.811 GiB, 18.87% gc time)
# 79 of 90 saved
#   5.862400 seconds (438.82 M allocations: 6.811 GiB, 19.00% gc time)
# 80 of 90 saved
#   5.602263 seconds (438.82 M allocations: 6.811 GiB, 18.97% gc time)
# 81 of 90 saved
#   5.594901 seconds (438.82 M allocations: 6.811 GiB, 18.75% gc time)
# 82 of 90 saved
#   5.589762 seconds (438.82 M allocations: 6.811 GiB, 18.86% gc time)
# 83 of 90 saved
#   5.684876 seconds (438.82 M allocations: 6.811 GiB, 19.16% gc time)
# 84 of 90 saved
#   5.558888 seconds (438.82 M allocations: 6.811 GiB, 18.93% gc time)
# 85 of 90 saved
#   5.575579 seconds (438.82 M allocations: 6.811 GiB, 18.79% gc time)
# 86 of 90 saved
#   5.681857 seconds (438.82 M allocations: 6.811 GiB, 19.12% gc time)
# 87 of 90 saved
#   5.793706 seconds (438.82 M allocations: 6.811 GiB, 19.02% gc time)
# 88 of 90 saved
#   5.578414 seconds (438.82 M allocations: 6.811 GiB, 18.95% gc time)
# 89 of 90 saved
#   5.677929 seconds (438.82 M allocations: 6.811 GiB, 19.38% gc time)
# 90 of 90 saved
