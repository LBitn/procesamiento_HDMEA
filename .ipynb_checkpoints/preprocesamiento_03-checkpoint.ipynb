# %%
 # path to SCPs
SCPpath = "/home/isabel/Dropbox/Proyects/Romero-Gutierrez/Scripts/Preprocesamiento/"
cd( SCPpath )
push!( LOAD_PATH, "." ); # folder que continen los modulos. Correr desde ahí dentro.
using AllFunctions # modulo personal
using JLD, Statistics

# %%
Γ = OS( "linux" ); # establecer SO 
BRWpath = "/home/isabel/Desktop/200819/" # path donde están los experimentos
BRWdirs = find_dirs( BRWpath, Γ ); # todos los exp ya con carpeta propia (output de pp01)
#
if isempty( BRWdirs )
    error(" Run preprocesamiento_01 first ")
end
#
A = 1; # para seleccionar que brw (ya en cachos) se vá a desaturar
NoSatpath = string( BRWdirs[ A ], Γ, "NoSat" ); # solo en primero, se puede hacer loop!
Varspath = string( BRWdirs[ A ], Γ, "Vars" );
#
if !isdir(NoSatpath)
    error(" NoSat folder not found, run preprocesamiento_02 first ")
else
    JLDfiles = find_files( NoSatpath, "jld", Γ ); # todos los cachos
end
#
if !isdir( Varspath )
    error( "No Vars folder yet, is output of pp01, soooo....." );
else
    vars = load( string( Varspath, Γ, "vars.jld" ) )[ "vars" ];
    NoSubs = load( string( Varspath, Γ, "NoChFr.jld" ) );
    SamplingRate = vars[ "SamplingRate" ];
end
#
Eventspath = string( BRWdirs[ A ], Γ, "Events" );
checkpath( Eventspath )
#
### Cambia el nombre de la carpeta de salida dependiendo del an'alisis a realizar
Outputpath = string( Eventspath, Γ, "Raw_Stc" );
checkpath( Outputpath )

# %%
cte = 3; 
d = Int( ceil( ( 1 * SamplingRate )/1000 ) );
min_thr = -20;

for B = 1:size( JLDfiles, 1 );
    NoChs = sort( NoSubs[ "SatChs" ][ B ] );
    data = load( JLDfiles[ B ] )[ "data" ];
    nchs = size( data, 1 );
    
    thrs = cte.*( -1 .* median( abs.( Float32.( data ) ), dims = 2 ) ./ 0.6745 );
    stds = std( Float32.( data ), dims = 2 );

    TOOhi = vars[ "Chs" ][ vec( thrs ) .< ( mean( vec( thrs ) ) + ( -cte*mean( vec( stds ) ) ) ), 1 ];
    TOOlow = vars[ "Chs" ][ vec( thrs ) .> min_thr, 1 ];
    NoChsSTD = vcat( TOOhi, TOOlow );
    
    NoChs = sort( unique( vcat( NoChsSTD, NoChs ) ) );
    
    MAYBES = zeros( Float32, nchs, 3 );
    Events = Dict( );
    
    for C = 1:nchs
        if in( C, NoChs )
            global MAYBES[ C ] = 0;
            FV = [ ];
        else
            ch = data[ C, : ];
    #        ch = filt( digitalfilter( responsetype, designmethod ), ch );
            FV = ESU( ch, thrs[ C ], d );
            FV[ :, 1 ] = FV[ :, 1 ] .+ ( ( B - 1 )*size( data, 2 ) );
        end
        MAYBES[ C ] = size( FV, 1 );
        temp = Dict(
            "Fr_Vol"   => FV,
         );
        get!( Events, string( C ), temp );
    end
    MAYBES[ :, 2 ] = thrs;
    MAYBES[ :, 3 ] = stds;
    Outputname = string( Outputpath, Γ, basename( JLDfiles[ B ] ) );
    save( Outputname, "Channels", MAYBES, "Events", Events );
    println( basename( JLDfiles[ B ] ), " saved..." );
end
# Out:
# BIN01_000s-002s.jld saved...
# BIN02_002s-004s.jld saved...
# BIN03_004s-006s.jld saved...
# BIN04_006s-008s.jld saved...
# BIN05_008s-010s.jld saved...
# BIN06_010s-012s.jld saved...
# BIN07_012s-014s.jld saved...
# BIN08_014s-016s.jld saved...
# BIN09_016s-018s.jld saved...
# BIN10_018s-020s.jld saved...
# BIN11_020s-022s.jld saved...
# BIN12_022s-024s.jld saved...
# BIN13_024s-026s.jld saved...
# BIN14_026s-028s.jld saved...
# BIN15_028s-030s.jld saved...
# BIN16_030s-032s.jld saved...
# BIN17_032s-034s.jld saved...
# BIN18_034s-036s.jld saved...
# BIN19_036s-038s.jld saved...
# BIN20_038s-040s.jld saved...
# BIN21_040s-042s.jld saved...
# BIN22_042s-044s.jld saved...
# BIN23_044s-046s.jld saved...
# BIN24_046s-048s.jld saved...
# BIN25_048s-050s.jld saved...
# BIN26_050s-052s.jld saved...
# BIN27_052s-054s.jld saved...
# BIN28_054s-056s.jld saved...
# BIN29_056s-058s.jld saved...
# BIN30_058s-060s.jld saved...
# BIN31_060s-062s.jld saved...
# BIN32_062s-064s.jld saved...
# BIN33_064s-066s.jld saved...
# BIN34_066s-068s.jld saved...
# BIN35_068s-070s.jld saved...
# BIN36_070s-072s.jld saved...
# BIN37_072s-074s.jld saved...
# BIN38_074s-076s.jld saved...
# BIN39_076s-078s.jld saved...
# BIN40_078s-080s.jld saved...
# BIN41_080s-082s.jld saved...
# BIN42_082s-084s.jld saved...
# BIN43_084s-086s.jld saved...
# BIN44_086s-088s.jld saved...
# BIN45_088s-090s.jld saved...
# BIN46_090s-092s.jld saved...
# BIN47_092s-094s.jld saved...
# BIN48_094s-096s.jld saved...
# BIN49_096s-098s.jld saved...
# BIN50_098s-100s.jld saved...
# BIN51_100s-102s.jld saved...
# BIN52_102s-104s.jld saved...
# BIN53_104s-106s.jld saved...
# BIN54_106s-108s.jld saved...
# BIN55_108s-110s.jld saved...
# BIN56_110s-112s.jld saved...
# BIN57_112s-114s.jld saved...
# BIN58_114s-116s.jld saved...
# BIN59_116s-118s.jld saved...
# BIN60_118s-120s.jld saved...
# BIN61_120s-122s.jld saved...
# BIN62_122s-124s.jld saved...
# BIN63_124s-126s.jld saved...
# BIN64_126s-128s.jld saved...
# BIN65_128s-130s.jld saved...
# BIN66_130s-132s.jld saved...
# BIN67_132s-134s.jld saved...
# BIN68_134s-136s.jld saved...
# BIN69_136s-138s.jld saved...
# BIN70_138s-140s.jld saved...
# BIN71_140s-142s.jld saved...
# BIN72_142s-144s.jld saved...
# BIN73_144s-146s.jld saved...
# BIN74_146s-148s.jld saved...
# BIN75_148s-150s.jld saved...
# BIN76_150s-152s.jld saved...
# BIN77_152s-154s.jld saved...
# BIN78_154s-156s.jld saved...
# BIN79_156s-158s.jld saved...
# BIN80_158s-160s.jld saved...
# BIN81_160s-162s.jld saved...
# BIN82_162s-164s.jld saved...
# BIN83_164s-166s.jld saved...
# BIN84_166s-168s.jld saved...
# BIN85_168s-170s.jld saved...
# BIN86_170s-172s.jld saved...
# BIN87_172s-174s.jld saved...
# BIN88_174s-176s.jld saved...
# BIN89_176s-178s.jld saved...
# BIN90_178s-180s.jld saved...
